# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Data-Mining_Project Task-1</b></center>
# <center><b><h1>Heart-Dataset</b></center>
# <center><b><h1>Jeet Bhalodi (23031701006)</b></center>
# <pre>

# %% [markdown]
# # 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as nump
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Read csv or excel File

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # 3. See the First 10 Rows

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# # 4. See the Last 10 Rows

# %%
df.tail(10)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1015   58    1   0       128   216    0        0      131      1      2.2
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1015      1   3     3       0
# 1016      1   1     2       0
# 1017      1   2     3       0
# ...

# %% [markdown]
# # 5. Display Summary Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # 6. Summarize the DataFrame.

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# # 7. Access a specific column

# %%
df[['age','sex']]
# Out:
#       age  sex
# 0      52    1
# 1      53    1
# 2      70    1
# 3      61    1
# 4      62    0
# ...   ...  ...
# 1020   59    1
# 1021   60    1
# 1022   47    1
# 1023   50    0
# 1024   54    1
#
# [1025 rows x 2 columns]

# %% [markdown]
# # 8.Compute the sum of value

# %%
df.age.sum()
# Out:
# 55795

# %% [markdown]
# # 9. Compute the mean of value

# %%
df.age.mean()
# Out:
# 54.43414634146342

# %% [markdown]
# # 10. Find Minimun or Maximum values

# %%
df.age.min()
# Out:
# 29

# %%
df.age.max()
# Out:
# 77

# %% [markdown]
# # 11. What is the number of observations in the dataset?

# %%
df.shape[0]
# Out:
# 1025

# %% [markdown]
# # 12. What is the number of columns in the dataset?

# %%
df.shape[1]
# Out:
# 14

# %% [markdown]
# # 13. Print the name of all the columns.

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # 14. How is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1025, step=1)

# %% [markdown]
# # 15. Number of Unique Items ?

# %%
df["sex"].nunique()
# Out:
# 2

# %% [markdown]
# # 16. Display the histogram for Age attribute by discretizing it into 5 separate bins and counting the frequency for each bin.

# %%
df["age"].hist(bins=6)
plt.show()

# %% [markdown]
# # 17. A boxplot can also be used to show the distribution of values for each attribute.

# %%
df[['age', 'trestbps']].boxplot()
plt.show()

# %% [markdown]
# # 18.  Display scatter plot, we can use a scatter plot to visualize their joint distribution.

# %%
plt.scatter(df["age"],df["trestbps"],alpha = 0.5)
plt.xlabel("age")
plt.ylabel("trestbps")
plt.title("age vs trestbps")
plt.show()

# %% [markdown]
# # 19.  For the qualitative attribute (class), count the frequency for each of its distinct values.

# %%
pclass_counts = df['target'].value_counts()
pclass_counts
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# # 20. Check the item thalach type

# %%
df['thalach'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # 21. Access rows by their integer location

# %%
df.iloc[20:30,2:5]
# Out:
#     cp  trestbps  chol
# 20   2       140   185
# 21   0       106   223
# 22   0       104   208
# 23   2       135   252
# 24   2       120   209
# 25   0       145   307
# 26   2       130   233
# 27   1       136   319
# 28   2       130   256
# 29   0       180   327

# %% [markdown]
# # 22. Create a Random Numbered Array

# %%
arr2 = nump.random.rand(5)
arr2
# Out:
# array([0.82886819, 0.72264289, 0.13664543, 0.78503719, 0.23882988])

# %% [markdown]
# # 23. Delete a specific Column

# %%
df.drop(columns = 'chol')
# Out:
#       age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      52    1   0       125    0        1      168      0      1.0      2
# 1      53    1   0       140    1        0      155      1      3.1      0
# 2      70    1   0       145    0        1      125      1      2.6      0
# 3      61    1   0       148    0        1      161      0      0.0      2
# 4      62    0   0       138    1        1      106      0      1.9      1
# ...   ...  ...  ..       ...  ...      ...      ...    ...      ...    ...
# 1020   59    1   1       140    0        1      164      1      0.0      2
# 1021   60    1   0       125    0        0      141      1      2.8      1
# 1022   47    1   0       110    0        0      118      1      1.0      1
# 1023   50    0   0       110    0        0      159      0      0.0      2
# 1024   54    1   0       120    0        1      113      0      1.4      1
#
#       ca  thal  target
# 0      2     3       0
# ...

# %% [markdown]
# # 24.  Create a new Column

# %%
df['newchol'] = df['chol']*1
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  newchol
# 0         2   2     3       0      212
# ...

# %% [markdown]
# # 25. Indexing in 2D Array

# %%
arr = nump.random.randint(10,50,size=(5,5))
arr
# Out:
# array([[36, 27, 46, 10, 21],
#        [31, 20, 20, 16, 37],
#        [46, 42, 29, 25, 34],
#        [26, 46, 21, 43, 45],
#        [36, 14, 36, 23, 22]])

# %%
arr[3][2]
# Out:
# 37
